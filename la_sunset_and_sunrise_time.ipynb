# %%
import requests
from datetime import datetime, timedelta
import pandas as pd

def get_sunrise_sunset(lat, lng, date):
    """
    Fetch sunrise and sunset times for a given location and date.
    :param lat: Latitude of the location
    :param lng: Longitude of the location
    :param date: Date in 'YYYY-MM-DD' format
    :return: Tuple containing sunrise and sunset times in UTC
    """
    # Construct the URL with the given latitude, longitude, and date
    url = f"https://api.sunrisesunset.io/json?lat={lat}&lng={lng}&date={date}"
    # Make the GET request to the sunrise-sunset API
    response = requests.get(url)
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        sunrise = data['results']['sunrise']
        sunset = data['results']['sunset']
        return sunrise, sunset
    else:
        return None, None

def adjust_time(time_str, round_up=True):
    """
    Adjust time to the nearest 10 minutes. Rounds up or down based on the round_up parameter.
    :param time_str: Original time string in '%I:%M:%S %p' format
    :param round_up: Boolean indicating whether to round up or down
    :return: Adjusted time string in '%I:%M %p' format
    """
    # Parse the time string into a datetime object
    time = datetime.strptime(time_str + " UTC", '%I:%M:%S %p %Z')
    # Adjust the time based on the round_up parameter
    if round_up:
        additional_minutes = (10 - time.minute % 10) % 10
        adjusted_time = time + timedelta(minutes=additional_minutes)
    else:
        subtract_minutes = time.minute % 10
        adjusted_time = time - timedelta(minutes=subtract_minutes)
    # Return the adjusted time in the specified format
    return adjusted_time.strftime('%I:%M %p')

# Prepare to write to an Excel file using the openpyxl engine
writer = pd.ExcelWriter('Sunrise_Sunset_2023_LA.xlsx', engine='openpyxl')

# DataFrame to store all the data before writing to Excel
all_data = []

# Latitude and Longitude for Los Angeles
lat = 34.0522
lng = -118.2437

# Loop over each day of the year 2023
for single_date in pd.date_range(start='2023-01-01', end='2023-12-31'):
    date_str = single_date.strftime('%Y-%m-%d')
    sunrise, sunset = get_sunrise_sunset(lat, lng, date_str)
    if sunrise and sunset:
        adjusted_sunrise = adjust_time(sunrise, round_up=True)
        adjusted_sunset = adjust_time(sunset, round_up=False)
        # Collect data for each day
        all_data.append([date_str, adjusted_sunrise, adjusted_sunset])
    else:
        print(f"Unable to retrieve sunrise and sunset times for {date_str}.")

# Convert the collected data into a DataFrame
df = pd.DataFrame(all_data, columns=['Date', 'Adjusted Sunrise', 'Adjusted Sunset'])
# Write the DataFrame to the Excel file
df.to_excel(writer, index=False)

# Save the Excel file
writer.save()
# Out:
# <ipython-input-4-471bb3fc6b3a>:73: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
import requests
from datetime import datetime, timedelta
import pandas as pd

def get_sunrise_sunset(lat, lng, date):
    """
    Fetch sunrise and sunset times for a given location and date.
    :param lat: Latitude of the location
    :param lng: Longitude of the location
    :param date: Date in 'YYYY-MM-DD' format
    :return: Tuple containing sunrise and sunset times in UTC
    """
    url = f"https://api.sunrisesunset.io/json?lat={lat}&lng={lng}&date={date}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        sunrise = data['results']['sunrise']
        sunset = data['results']['sunset']
        return sunrise, sunset
    else:
        return None, None

def adjust_time(time_str, round_up=True):
    """
    Adjust time to the nearest 10 minutes. Rounds up for sunrise and rounds down for sunset.
    :param time_str: Original time string in '%I:%M:%S %p' format
    :param round_up: Boolean indicating whether to round up or down
    :return: Adjusted time string in '%I:%M %p' format
    """
    time = datetime.strptime(time_str + " UTC", '%I:%M:%S %p %Z')
    if round_up:
        additional_minutes = (10 - time.minute % 10) % 10  # Use %10 to handle cases exactly on a 10-minute mark
        adjusted_time = time + timedelta(minutes=additional_minutes)
    else:
        subtract_minutes = time.minute % 10
        adjusted_time = time - timedelta(minutes=subtract_minutes)
    return adjusted_time.strftime('%I:%M %p')



# Latitude and Longitude for Los Angeles
lat = 34.0522
lng = -118.2437

# Loop over each day of the year 2023
for single_date in pd.date_range(start='2023-01-01', end='2023-12-31'):
    date_str = single_date.strftime('%Y-%m-%d')
    sunrise, sunset = get_sunrise_sunset(lat, lng, date_str)
    if sunrise and sunset:
        adjusted_sunrise = adjust_time(sunrise, round_up=True)
        adjusted_sunset = adjust_time(sunset, round_up=False)
        print(f"Date: {date_str}, Adjusted Sunrise: {adjusted_sunrise}, Adjusted Sunset: {adjusted_sunset}")
        # Assuming you'll perform further operations to create a DataFrame
        # and write it to the Excel file, similar to this:
        # df.to_excel(writer, sheet_name=date_str)
    else:
        print(f"Unable to retrieve sunrise and sunset times for {date_str}.")

# Don't forget to save the Excel file after processing all dates
writer.save()
# Out:
# Date: 2023-01-01, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-02, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-03, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-04, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-05, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-06, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-07, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-01-08, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-09, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-10, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-11, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-12, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-13, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-14, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-15, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-16, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-17, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-18, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:00 PM
# Date: 2023-01-19, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-20, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-21, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-22, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-23, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-24, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-25, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-26, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-27, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-28, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:10 PM
# Date: 2023-01-29, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-01-30, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-01-31, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-01, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-02, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-03, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-04, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-05, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-06, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-07, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:20 PM
# Date: 2023-02-08, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-09, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-10, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-11, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-12, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-13, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-14, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-15, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-16, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-17, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-18, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:30 PM
# Date: 2023-02-19, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-20, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-21, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-22, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-23, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-24, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-25, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-26, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-27, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-02-28, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-03-01, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:40 PM
# Date: 2023-03-02, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-03, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-04, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-05, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-06, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-07, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-08, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-09, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-10, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-11, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-12, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-03-13, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-03-14, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-03-15, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-16, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-17, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-18, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-19, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-20, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-21, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-22, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-23, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-24, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-25, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-26, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-27, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-03-28, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-03-29, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-03-30, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-03-31, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-01, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-02, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-03, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-04, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-05, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-06, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-07, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-08, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-09, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-04-10, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-11, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-12, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-13, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-14, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-15, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-16, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-17, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-18, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-19, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-20, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-21, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-22, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-04-23, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-24, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-25, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-26, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-27, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-28, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-29, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-04-30, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-05-01, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-05-02, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-05-03, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-05-04, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-05-05, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-05-06, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-07, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-08, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-09, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-10, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-11, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-12, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-13, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-14, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-15, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-16, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-17, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-18, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-05-19, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-20, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-21, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-22, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-23, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-24, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-25, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-26, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-27, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-28, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-29, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-30, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-05-31, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-06-01, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-06-02, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-03, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-04, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-05, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-06, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-07, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-08, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-09, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-10, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-11, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-12, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-13, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-14, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-15, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-16, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-17, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-18, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-19, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-20, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-21, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-22, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-23, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-24, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-25, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-26, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-27, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-28, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-29, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-06-30, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-01, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-02, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-03, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-04, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-05, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-06, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-07, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-08, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-09, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-10, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-11, Adjusted Sunrise: 05:50 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-12, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-13, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-14, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-15, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-16, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-17, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-18, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-19, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-20, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-21, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-22, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-23, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-24, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-25, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-26, Adjusted Sunrise: 06:00 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-27, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 08:00 PM
# Date: 2023-07-28, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-07-29, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-07-30, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-07-31, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-01, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-02, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-03, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-04, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-05, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-06, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-07, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-08, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:50 PM
# Date: 2023-08-09, Adjusted Sunrise: 06:10 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-10, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-11, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-12, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-13, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-14, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-15, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-16, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-17, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:40 PM
# Date: 2023-08-18, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-19, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-20, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-21, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-22, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-23, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-24, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-25, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-26, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:30 PM
# Date: 2023-08-27, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-08-28, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-08-29, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-08-30, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-08-31, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-09-01, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-09-02, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:20 PM
# Date: 2023-09-03, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-04, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-05, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-06, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-07, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-08, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-09, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-10, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:10 PM
# Date: 2023-09-11, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-12, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-13, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-14, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-15, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-16, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-17, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 07:00 PM
# Date: 2023-09-18, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-19, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-20, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-21, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-22, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-23, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-24, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:50 PM
# Date: 2023-09-25, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-09-26, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-09-27, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-09-28, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-09-29, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-09-30, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-10-01, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:40 PM
# Date: 2023-10-02, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-03, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-04, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-05, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-06, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-07, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-08, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:30 PM
# Date: 2023-10-09, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-10, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-11, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-12, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-13, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-14, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-15, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-16, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:20 PM
# Date: 2023-10-17, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-18, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-19, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-20, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-21, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-22, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-23, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-24, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-25, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:10 PM
# Date: 2023-10-26, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-10-27, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-10-28, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-10-29, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-10-30, Adjusted Sunrise: 07:10 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-10-31, Adjusted Sunrise: 07:20 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-11-01, Adjusted Sunrise: 07:20 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-11-02, Adjusted Sunrise: 07:20 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-11-03, Adjusted Sunrise: 07:20 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-11-04, Adjusted Sunrise: 07:20 AM, Adjusted Sunset: 06:00 PM
# Date: 2023-11-05, Adjusted Sunrise: 07:20 AM, Adjusted Sunset: 05:50 PM
# Date: 2023-11-06, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-07, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-08, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-09, Adjusted Sunrise: 06:20 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-10, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-11, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-12, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-13, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-14, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-15, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-16, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-17, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-11-18, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-19, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-20, Adjusted Sunrise: 06:30 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-21, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-22, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-23, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-24, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-25, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-26, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-27, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-28, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-29, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-11-30, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-01, Adjusted Sunrise: 06:40 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-02, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-03, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-04, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-05, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-06, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-07, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-08, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-09, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-10, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-11, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-12, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-13, Adjusted Sunrise: 06:50 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-14, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-15, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-16, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-17, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-18, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-19, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-20, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-21, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-22, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-23, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-24, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:40 PM
# Date: 2023-12-25, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-12-26, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-12-27, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-12-28, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-12-29, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-12-30, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# Date: 2023-12-31, Adjusted Sunrise: 07:00 AM, Adjusted Sunset: 04:50 PM
# <ipython-input-5-3b8b4a41d248>:60: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
import pandas as pd
from datetime import datetime, timedelta

# Load the provided Excel file
input_file_path = '/content/Sunrise_Sunset_2023_LA.xlsx'
df = pd.read_excel(input_file_path)

# Create a new Excel writer object using pandas
output_file_path = '/content/Sunrise_Sunset_Intervals_2023_LA.xlsx'
with pd.ExcelWriter(output_file_path, engine='openpyxl') as writer:
    def create_intervals(sunrise, sunset):
        """
        Generate ten-minute intervals between sunrise and sunset times.
        """
        intervals = []
        current_time = sunrise
        while current_time <= sunset:
            intervals.append(current_time.strftime('%I:%M %p'))
            current_time += timedelta(minutes=10)
        return intervals

    for index, row in df.iterrows():
        date_str = row['Date']
        sunrise_str = row['Adjusted Sunrise']
        sunset_str = row['Adjusted Sunset']

        # Convert times to datetime objects
        sunrise_time = datetime.strptime(sunrise_str, '%I:%M %p')
        sunset_time = datetime.strptime(sunset_str, '%I:%M %p')

        # Generate ten-minute intervals
        intervals = create_intervals(sunrise_time, sunset_time)

        # Create a DataFrame for the intervals
        df_intervals = pd.DataFrame({'Time': intervals})

        # Format the date as YYYY_MM_DD for the sheet name
        sheet_name = datetime.strptime(date_str, '%Y-%m-%d').strftime('%Y_%m_%d')
        # Save the DataFrame to a new sheet in the workbook
        df_intervals.to_excel(writer, sheet_name=sheet_name, index=False)

# Indicate success and the path to the saved file
print(f"Intervals Excel file has been saved: {output_file_path}")
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x7d6cf3ee6320>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/zipfile.py", line 1821, in __del__
#     self.close()
#   File "/usr/lib/python3.10/zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# Intervals Excel file has been saved: /content/Sunrise_Sunset_Intervals_2023_LA.xlsx
